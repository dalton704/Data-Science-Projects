# %%
import seaborn as sns

# %%
diamonds = sns.load_dataset('diamonds')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy  import stats

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
# Carat dustribution
fig = plt.figure(figsize=(10, 7.5))
sns.distplot(diamonds['carat'][diamonds['carat'] > 0].values, kde=False, bins=75)
# Out:
# <AxesSubplot:>

# %%
# Amount of carats per cut
fig = plt.figure(figsize=(10,7.5))
sns.countplot(x='cut', data=diamonds[diamonds['carat'] == True], color = 'darkblue')
# Out:
# <AxesSubplot:xlabel='cut', ylabel='count'>

# %%
# Price of Carats
fig = plt.figure(figsize=(10,7.5))
sns.boxplot(x='price', data=diamonds[diamonds['carat'] == True], color = 'darkblue')
# Out:
# <AxesSubplot:xlabel='price'>

# %%
# COMparing the amount of colors per cut
fig = plt.figure(figsize=(16,7.5))
sns.countplot(x='cut', hue='color',data=diamonds)
# Out:
# <AxesSubplot:xlabel='cut', ylabel='count'>

# %%
# Amount of each color
fig = plt.figure(figsize=(10,7.5))
sns.countplot(x='color', data=diamonds[diamonds['carat'] == True], color='darkblue')
# Out:
# <AxesSubplot:xlabel='color', ylabel='count'>

# %%
# price distribution
fig = plt.figure(figsize=(10, 7.5))
sns.distplot(diamonds['price'][diamonds['price'] > 0].values, kde=False, bins=75)
# Out:
# C:\Users\lokum\OneDrive\Documents\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:>

# %%
color_proportion = diamonds.groupby(['cut', 'color']).agg({'price': 'count'})
color_proportion
# Out:
#                  price
# cut       color
# Ideal     D       2834
#           E       3903
#           F       3826
#           G       4884
#           H       3115
#           I       2093
#           J        896
# Premium   D       1603
#           E       2337
#           F       2331
#           G       2924
#           H       2360
#           I       1428
#           J        808
# Very Good D       1513
#           E       2400
#           F       2164
#           G       2299
#           H       1824
#           I       1204
#           J        678
# Good      D        662
#           E        933
#           F        909
#           G        871
#           H        702
#           I        522
#           J        307
# Fair      D        163
#           E        224
#           F        312
#           G        314
#           H        303
#           I        175
#           J        119

# %%
color_proportion.groupby(level=0).apply(lambda x: 100 * x / float(x.sum()))
# Out:
#                      price
# cut       color
# Ideal     D      13.150202
#           E      18.110529
#           F      17.753237
#           G      22.662521
#           H      14.454086
#           I       9.711846
#           J       4.157580
# Premium   D      11.623523
#           E      16.945834
#           F      16.902328
#           G      21.202233
#           H      17.112610
#           I      10.354579
#           J       5.858893
# Very Good D      12.522761
#           E      19.864261
#           F      17.910942
#           G      19.028307
#           H      15.096838
#           I       9.965238
#           J       5.611654
# Good      D      13.493681
#           E      19.017530
#           F      18.528333
#           G      17.753771
#           H      14.309009
#           I      10.640033
#           J       6.257644
# Fair      D      10.124224
#           E      13.913043
#           F      19.378882
#           G      19.503106
# ...
